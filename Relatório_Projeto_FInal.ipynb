# %%
# !pip install opencv-python --upgrade
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2 as cv
import time
from timeit import default_timer as timer
import matplotlib.pyplot as plt
import pickle
from keras.models import load_model
# Out:
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/6d/80/10a9ae6fa0940f25af32739d1dc6dfdbbdc79af3f04c5ea1a6de4303cd54/opencv_python-4.4.0.46-cp36-cp36m-manylinux2014_x86_64.whl (49.5MB)
#      |████████████████████████████████| 49.5MB 96kB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.18.5)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-4.4.0.46

# %%
print( cv.__version__ )
# Out:
# 4.4.0

# %%
# !pip install kaggle -q
# !mkdir .kaggle
import json
token = {"username":"someonetest","key":"8790cbd05d258df3a0fec2ffb25d689d"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json --force
# !kaggle config set -n path -v{/content}
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d mlg-ulb/creditcardfraud -p /content --force
# !kaggle datasets download -d valentynsichkar/traffic-signs-preprocessed -p /content --force
# !unzip \*.zip
# Out:
# mkdir: cannot create directory ‘.kaggle’: File exists
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# - path is now set to: {/content}
# Downloading traffic-signs-preprocessed.zip to /content
# 100% 4.16G/4.16G [00:53<00:00, 75.7MB/s]
# 100% 4.16G/4.16G [00:53<00:00, 83.0MB/s]
# Archive:  traffic-signs-preprocessed.zip
#   inflating: data0.pickle
#   inflating: data1.pickle
#   inflating: data2.pickle
#   inflating: data3.pickle
#   inflating: data4.pickle
#   inflating: data5.pickle
#   inflating: data6.pickle
#   inflating: data7.pickle
#   inflating: data8.pickle
#   inflating: datasets_preparing.py
#   inflating: label_names.csv
#   inflating: labels.pickle
#   inflating: mean_image_gray.pickle
#   inflating: mean_image_rgb.pickle
#   inflating: std_gray.pickle
#   inflating: std_rgb.pickle
#   inflating: test.pickle
#   inflating: train.pickle
#   inflating: valid.pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ln -s /content/drive/MyDrive/Projeto_Machine/Modelos/ /mydrive
# !ls /mydrive
# Out:
#  Classificação	       'Resultado 5 épocas'   test_video.mp4
#  localizacao	        test_3.jpg	      traffic-sign-to-test.mp4
#  ResNet50_model2.h5     test_8.jpg	      yolov4-obj_best.weights
#  ResNet50_model.h5      teste_image.png       yolov4-obj.cfg
# 'Resultado 10 épocas'   test_video2.mp4       yolov4-obj_last.weights

# %%
labels = pd.read_csv('label_names.csv')
# labels

# %%
# Loading trained CNN model to use it later when classifying from 4 groups into one of 43 classes
# model = load_model('/mydrive/ResNet50_model.h5')
model = load_model('/mydrive/ResNet50_model2.h5')

# Loading mean image to use for preprocessing further
# Opening file for reading in binary mode
with open('mean_image_rgb.pickle', 'rb') as f:
    mean = pickle.load(f, encoding='latin1')  # dictionary type
    
print(mean['mean_image_rgb'].shape)  # (3, 32, 32)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 200, 200, 3) for input Tensor("input_6:0", shape=(None, 200, 200, 3), dtype=float32), but it was called on an input with incompatible shape (None, 256, 256, 3).
# (3, 32, 32)

# %%
# Trained weights can be found in the course mentioned above
path_to_weights = '/mydrive/yolov4-obj_last.weights'
path_to_cfg = '/mydrive/yolov4-obj.cfg'

#Using YOLOv3 to video
# path_to_weights = '/mydrive/localizacao/yolov3/backup/yolov3_custom_last.weights'
# path_to_cfg = '/mydrive/localizacao/yolov3/yolov3_custom.cfg'

# Loading trained YOLO v3 weights and cfg configuration file by 'dnn' library from OpenCV
network = cv.dnn_DetectionModel(path_to_cfg, path_to_weights)

# To use with GPU
network.setPreferableBackend(cv.dnn.DNN_BACKEND_OPENCV)
network.setPreferableTarget(cv.dnn.DNN_TARGET_OPENCL_FP16)

# %%
# Getting names of all YOLO v3 layers
layers_all = network.getLayerNames()

# Check point
# print(layers_all)

# Getting only detection YOLO v3 layers that are 82, 94 and 106
layers_names_output = [layers_all[i[0] - 1] for i in network.getUnconnectedOutLayers()]

# Check point
print()
print(layers_names_output)  # ['yolo_82', 'yolo_94', 'yolo_106']
# Out:
# ['yolo_82', 'yolo_94', 'yolo_106']

# %%
# Minimum probability to eliminate weak detections
probability_minimum = 0.3

# Setting threshold to filtering weak bounding boxes by non-maximum suppression
threshold = 0.3

# Generating colours for bounding boxes
# randint(low, high=None, size=None, dtype='l')
colours = np.random.randint(0, 255, size=(len(labels), 3), dtype='uint8')

# Check point
print(type(colours))  # <class 'numpy.ndarray'>
print(colours.shape)  # (43, 3)
print(colours[0])  # [25  65 200]
# Out:
# <class 'numpy.ndarray'>
# (43, 3)
# [ 12  63 211]

# %%
# Reading video from a file by VideoCapture object
# video = cv2.VideoCapture('../input/traffic-signs-dataset-in-yolo-format/traffic-sign-to-test.mp4')
# video = cv2.VideoCapture('../input/videofortesting/ts_video_1.mp4')
# video = cv.VideoCapture('/mydrive/traffic-sign-to-test.mp4')
video = cv.VideoCapture('/mydrive/test_video.mp4')
# video = cv.VideoCapture('/mydrive/test_video2.mp4')


# Writer that will be used to write processed frames
writer = None

# Variables for spatial dimensions of the frames
h, w = None, None

# %%
# %matplotlib inline

# Setting default size of plots
plt.rcParams['figure.figsize'] = (3, 3)

# Variable for counting total amount of frames
f = 0

# Variable for counting total processing time
t = 0

# Catching frames in the loop
while True:
    # Capturing frames one-by-one
    ret, frame = video.read()

    # If the frame was not retrieved
    if not ret:
        break
       
    # Getting spatial dimensions of the frame for the first time
    if w is None or h is None:
        # Slicing two elements from tuple
        h, w = frame.shape[:2]

    # Blob from current frame
    blob = cv.dnn.blobFromImage(frame, 1 / 255.0, (416, 416), swapRB=True, crop=False)

    # Forward pass with blob through output layers
    network.setInput(blob)
    start = time.time()
    output_from_network = network.forward(layers_names_output)
    end = time.time()

    # Increasing counters
    f += 1
    t += end - start

    # Spent time for current frame
    print('Frame number {0} took {1:.5f} seconds'.format(f, end - start))

    # Lists for detected bounding boxes, confidences and class's number
    bounding_boxes = []
    confidences = []
    class_numbers = []

    # Going through all output layers after feed forward pass
    for result in output_from_network:
        # Going through all detections from current output layer
        for detected_objects in result:
            # Getting 80 classes' probabilities for current detected object
            scores = detected_objects[5:]
            # Getting index of the class with the maximum value of probability
            class_current = np.argmax(scores)
            # Getting value of probability for defined class
            confidence_current = scores[class_current]

            # Eliminating weak predictions by minimum probability
            if confidence_current > probability_minimum:
                # Scaling bounding box coordinates to the initial frame size
                box_current = detected_objects[0:4] * np.array([w, h, w, h])

                # Getting top left corner coordinates
                x_center, y_center, box_width, box_height = box_current
                x_min = int(x_center - (box_width / 2))
                y_min = int(y_center - (box_height / 2))

                # Adding results into prepared lists
                bounding_boxes.append([x_min, y_min, int(box_width), int(box_height)])
                confidences.append(float(confidence_current))
                class_numbers.append(class_current)
                

    # Implementing non-maximum suppression of given bounding boxes
    results = cv.dnn.NMSBoxes(bounding_boxes, confidences, probability_minimum, threshold)

    # Checking if there is any detected object been left
    if len(results) > 0:
        # Going through indexes of results
        for i in results.flatten():
            # Bounding box coordinates, its width and height
            x_min, y_min = bounding_boxes[i][0], bounding_boxes[i][1]
            box_width, box_height = bounding_boxes[i][2], bounding_boxes[i][3]
            
            
            # Cut fragment with Traffic Sign
            c_ts = frame[y_min:y_min+int(box_height), x_min:x_min+int(box_width), :]
            # print(c_ts.shape)
            
            if c_ts.shape[:1] == (0,) or c_ts.shape[1:2] == (0,):
                pass
            else:
                # Getting preprocessed blob with Traffic Sign of needed shape
                blob_ts = cv.dnn.blobFromImage(c_ts, 1 / 255.0, size=(32, 32), swapRB=True, crop=False)
                blob_ts[0] = blob_ts[0, :, :, :] - mean['mean_image_rgb']
                blob_ts = blob_ts.transpose(0, 2, 3, 1)
                # plt.imshow(blob_ts[0, :, :, :])L
                # plt.show()

                # Feeding to the Keras CNN model to get predicted label among 43 classes
                scores = model.predict(blob_ts)

                # Scores is given for image with 43 numbers of predictions for each class
                # Getting only one class with maximum value
                prediction = np.argmax(scores)
                # print(labels['SignName'][prediction])


                # Colour for current bounding box
                colour_box_current = colours[class_numbers[i]].tolist()

                # Drawing bounding box on the original current frame
                cv.rectangle(frame, (x_min, y_min),
                              (x_min + box_width, y_min + box_height),
                              colour_box_current, 2)

                # Preparing text with label and confidence for current bounding box
                text_box_current = '{}: {:.4f}'.format(labels['SignName'][prediction],
                                                       confidences[i])

                # Putting text with label and confidence on the original image
                cv.putText(frame, text_box_current, (x_min, y_min - 5),
                            cv.FONT_HERSHEY_SIMPLEX, 0.5, colour_box_current, 2)


    # Initializing writer only once
    if writer is None:
        fourcc = cv.VideoWriter_fourcc(*'mp4v')

        # Writing current processed frame into the video file
        writer = cv.VideoWriter('result.mp4', fourcc, 25,
                                 (frame.shape[1], frame.shape[0]), True)

    # Write processed current frame to the file
    writer.write(frame)


# Releasing video reader and writer
video.release()
writer.release()
# Out:
# Frame number 1 took 1.27610 seconds
# Frame number 2 took 1.25930 seconds
# Frame number 3 took 1.27841 seconds
# Frame number 4 took 1.25647 seconds
# Frame number 5 took 1.25561 seconds
# Frame number 6 took 1.25566 seconds
# Frame number 7 took 1.28225 seconds
# Frame number 8 took 1.25034 seconds
# Frame number 9 took 1.27599 seconds
# Frame number 10 took 1.28280 seconds
# Frame number 11 took 1.24825 seconds
# Frame number 12 took 1.25992 seconds
# Frame number 13 took 1.26258 seconds
# Frame number 14 took 1.25636 seconds
# Frame number 15 took 1.28677 seconds
# Frame number 16 took 1.27908 seconds
# Frame number 17 took 1.26213 seconds
# Frame number 18 took 1.25509 seconds
# Frame number 19 took 1.26486 seconds
# Frame number 20 took 1.25339 seconds
# Frame number 21 took 1.25425 seconds
# Frame number 22 took 1.25775 seconds
# Frame number 23 took 1.26242 seconds
# Frame number 24 took 1.26104 seconds
# Frame number 25 took 1.27007 seconds
# Frame number 26 took 1.25950 seconds
# Frame number 27 took 1.25220 seconds
# Frame number 28 took 1.26479 seconds
# Frame number 29 took 1.25566 seconds
# Frame number 30 took 1.27737 seconds
# Frame number 31 took 1.26387 seconds
# Frame number 32 took 1.25403 seconds
# Frame number 33 took 1.26673 seconds
# Frame number 34 took 1.28395 seconds
# Frame number 35 took 1.25414 seconds
# Frame number 36 took 1.25423 seconds
# Frame number 37 took 1.24973 seconds
# Frame number 38 took 1.26417 seconds
# Frame number 39 took 1.26168 seconds
# Frame number 40 took 1.29171 seconds
# Frame number 41 took 1.27326 seconds
# Frame number 42 took 1.26431 seconds
# Frame number 43 took 1.27756 seconds
# Frame number 44 took 1.26226 seconds
# Frame number 45 took 1.25800 seconds
# Frame number 46 took 1.30185 seconds
# Frame number 47 took 1.26921 seconds
# Frame number 48 took 1.25655 seconds
# Frame number 49 took 1.25392 seconds
# Frame number 50 took 1.26732 seconds
# Frame number 51 took 1.26465 seconds
# Frame number 52 took 1.28672 seconds
# Frame number 53 took 1.25883 seconds
# Frame number 54 took 1.26278 seconds
# Frame number 55 took 1.25573 seconds
# Frame number 56 took 1.25692 seconds
# Frame number 57 took 1.25014 seconds
# Frame number 58 took 1.24945 seconds
# Frame number 59 took 1.25389 seconds
# Frame number 60 took 1.26554 seconds
# Frame number 61 took 1.25231 seconds
# Frame number 62 took 1.26844 seconds
# Frame number 63 took 1.25812 seconds
# Frame number 64 took 1.25964 seconds
# Frame number 65 took 1.28215 seconds
# Frame number 66 took 1.26566 seconds
# Frame number 67 took 1.25174 seconds
# Frame number 68 took 1.26291 seconds
# Frame number 69 took 1.29211 seconds
# Frame number 70 took 1.26073 seconds
# Frame number 71 took 1.27782 seconds
# Frame number 72 took 1.25634 seconds
# Frame number 73 took 1.25019 seconds
# Frame number 74 took 1.25231 seconds
# Frame number 75 took 1.26380 seconds
# Frame number 76 took 1.28339 seconds
# Frame number 77 took 1.26743 seconds
# Frame number 78 took 1.28098 seconds
# Frame number 79 took 1.25483 seconds
# Frame number 80 took 1.26410 seconds
# Frame number 81 took 1.27259 seconds
# Frame number 82 took 1.28773 seconds
# Frame number 83 took 1.28640 seconds
# Frame number 84 took 1.25460 seconds
# Frame number 85 took 1.27041 seconds
# Frame number 86 took 1.26835 seconds
# Frame number 87 took 1.27063 seconds
# Frame number 88 took 1.26895 seconds
# Frame number 89 took 1.29108 seconds
# Frame number 90 took 1.25976 seconds
# Frame number 91 took 1.26785 seconds
# Frame number 92 took 1.25952 seconds
# Frame number 93 took 1.27255 seconds
# Frame number 94 took 1.26154 seconds
# Frame number 95 took 1.29980 seconds
# Frame number 96 took 1.27167 seconds
# Frame number 97 took 1.27643 seconds
# Frame number 98 took 1.26130 seconds
# Frame number 99 took 1.26877 seconds
# Frame number 100 took 1.26085 seconds
# Frame number 101 took 1.29841 seconds
# Frame number 102 took 1.26022 seconds
# Frame number 103 took 1.28198 seconds
# Frame number 104 took 1.29646 seconds
# Frame number 105 took 1.26911 seconds
# Frame number 106 took 1.25918 seconds
# Frame number 107 took 1.28948 seconds
# Frame number 108 took 1.24962 seconds
# Frame number 109 took 1.25377 seconds
# Frame number 110 took 1.26790 seconds
# Frame number 111 took 1.26040 seconds
# Frame number 112 took 1.26008 seconds
# Frame number 113 took 1.25052 seconds
# Frame number 114 took 1.25423 seconds
# Frame number 115 took 1.25743 seconds
# Frame number 116 took 1.25503 seconds
# Frame number 117 took 1.25309 seconds
# Frame number 118 took 1.28278 seconds
# Frame number 119 took 1.25586 seconds
# Frame number 120 took 1.28744 seconds
# Frame number 121 took 1.25846 seconds
# Frame number 122 took 1.27308 seconds
# Frame number 123 took 1.26156 seconds
# Frame number 124 took 1.26273 seconds
# Frame number 125 took 1.25722 seconds
# Frame number 126 took 1.25836 seconds
# Frame number 127 took 1.26201 seconds
# Frame number 128 took 1.24887 seconds
# Frame number 129 took 1.24947 seconds
# Frame number 130 took 1.25692 seconds
# Frame number 131 took 1.29270 seconds
# Frame number 132 took 1.27149 seconds
# Frame number 133 took 1.25178 seconds
# Frame number 134 took 1.25834 seconds
# Frame number 135 took 1.25813 seconds
# Frame number 136 took 1.27440 seconds
# Frame number 137 took 1.30548 seconds
# Frame number 138 took 1.26160 seconds
# Frame number 139 took 1.27859 seconds
# Frame number 140 took 1.27449 seconds
# Frame number 141 took 1.25369 seconds
# Frame number 142 took 1.26092 seconds
# Frame number 143 took 1.27502 seconds
# Frame number 144 took 1.24473 seconds
# Frame number 145 took 1.26299 seconds
# Frame number 146 took 1.26976 seconds
# Frame number 147 took 1.26012 seconds
# Frame number 148 took 1.26074 seconds
# Frame number 149 took 1.25372 seconds
# Frame number 150 took 1.26259 seconds
# Frame number 151 took 1.25348 seconds
# Frame number 152 took 1.27479 seconds
# Frame number 153 took 1.25617 seconds
# Frame number 154 took 1.25390 seconds
# Frame number 155 took 1.24862 seconds
# Frame number 156 took 1.25465 seconds
# Frame number 157 took 1.25477 seconds
# Frame number 158 took 1.25285 seconds
# Frame number 159 took 1.24870 seconds
# Frame number 160 took 1.25322 seconds
# Frame number 161 took 1.25977 seconds
# Frame number 162 took 1.25733 seconds
# Frame number 163 took 1.26384 seconds
# Frame number 164 took 1.25462 seconds
# Frame number 165 took 1.24934 seconds
# Frame number 166 took 1.27438 seconds
# Frame number 167 took 1.27112 seconds
# Frame number 168 took 1.24908 seconds
# Frame number 169 took 1.27795 seconds
# Frame number 170 took 1.27540 seconds
# Frame number 171 took 1.24910 seconds
# Frame number 172 took 1.27406 seconds
# Frame number 173 took 1.26018 seconds
# Frame number 174 took 1.26171 seconds
# Frame number 175 took 1.25701 seconds
# Frame number 176 took 1.26299 seconds
# Frame number 177 took 1.26329 seconds
# Frame number 178 took 1.25346 seconds
# Frame number 179 took 1.27372 seconds
# Frame number 180 took 1.27160 seconds
# Frame number 181 took 1.25481 seconds
# Frame number 182 took 1.28065 seconds
# Frame number 183 took 1.24975 seconds
# Frame number 184 took 1.25893 seconds
# Frame number 185 took 1.28138 seconds
# Frame number 186 took 1.24959 seconds
# Frame number 187 took 1.25296 seconds
# Frame number 188 took 1.25142 seconds
# Frame number 189 took 1.24991 seconds
# Frame number 190 took 1.27324 seconds
# Frame number 191 took 1.24641 seconds
# Frame number 192 took 1.26459 seconds
# Frame number 193 took 1.26260 seconds
# Frame number 194 took 1.24796 seconds
# Frame number 195 took 1.24378 seconds
# Frame number 196 took 1.24678 seconds
# Frame number 197 took 1.26028 seconds
# Frame number 198 took 1.25664 seconds
# Frame number 199 took 1.29547 seconds
# Frame number 200 took 1.26050 seconds
# Frame number 201 took 1.25395 seconds
# Frame number 202 took 1.25015 seconds
# Frame number 203 took 1.25066 seconds
# Frame number 204 took 1.27503 seconds
# Frame number 205 took 1.24573 seconds
# Frame number 206 took 1.25014 seconds
# Frame number 207 took 1.28700 seconds
# Frame number 208 took 1.25241 seconds
# Frame number 209 took 1.25333 seconds
# Frame number 210 took 1.25966 seconds
# Frame number 211 took 1.26019 seconds
# Frame number 212 took 1.25431 seconds
# Frame number 213 took 1.28523 seconds
# Frame number 214 took 1.26069 seconds
# Frame number 215 took 1.26193 seconds
# Frame number 216 took 1.25801 seconds
# Frame number 217 took 1.24631 seconds
# Frame number 218 took 1.27413 seconds
# Frame number 219 took 1.25451 seconds
# Frame number 220 took 1.24656 seconds
# Frame number 221 took 1.24404 seconds
# Frame number 222 took 1.24593 seconds
# Frame number 223 took 1.26521 seconds
# Frame number 224 took 1.28408 seconds
# Frame number 225 took 1.26669 seconds
# Frame number 226 took 1.26145 seconds
# Frame number 227 took 1.24830 seconds
# Frame number 228 took 1.26245 seconds
# Frame number 229 took 1.25682 seconds
# Frame number 230 took 1.25135 seconds
# Frame number 231 took 1.25346 seconds
# Frame number 232 took 1.25923 seconds
# Frame number 233 took 1.25698 seconds
# Frame number 234 took 1.28105 seconds
# Frame number 235 took 1.27817 seconds
# Frame number 236 took 1.26231 seconds
# Frame number 237 took 1.25447 seconds
# Frame number 238 took 1.26072 seconds
# Frame number 239 took 1.25386 seconds
# Frame number 240 took 1.27839 seconds
# Frame number 241 took 1.27155 seconds
# Frame number 242 took 1.25989 seconds
# Frame number 243 took 1.25894 seconds
# Frame number 244 took 1.56979 seconds
# Frame number 245 took 1.26059 seconds
# Frame number 246 took 1.30077 seconds
# Frame number 247 took 1.26110 seconds
# Frame number 248 took 1.26137 seconds
# Frame number 249 took 1.25524 seconds
# Frame number 250 took 1.25612 seconds
# Frame number 251 took 1.26132 seconds
# Frame number 252 took 1.29045 seconds
# Frame number 253 took 1.25271 seconds
# Frame number 254 took 1.25537 seconds
# Frame number 255 took 1.24946 seconds
# Frame number 256 took 1.26371 seconds
# Frame number 257 took 1.25756 seconds
# Frame number 258 took 1.28268 seconds
# Frame number 259 took 1.24751 seconds
# Frame number 260 took 1.24961 seconds
# Frame number 261 took 1.26235 seconds
# Frame number 262 took 1.26866 seconds
# Frame number 263 took 1.29498 seconds
# Frame number 264 took 1.32954 seconds
# Frame number 265 took 1.32943 seconds
# Frame number 266 took 1.28724 seconds
# Frame number 267 took 1.29342 seconds
# Frame number 268 took 1.28385 seconds
# Frame number 269 took 1.28984 seconds
# Frame number 270 took 1.25959 seconds
# Frame number 271 took 1.25840 seconds
# Frame number 272 took 1.25681 seconds
# Frame number 273 took 1.27816 seconds
# Frame number 274 took 1.25037 seconds
# Frame number 275 took 1.25090 seconds
# Frame number 276 took 1.27634 seconds
# Frame number 277 took 1.27215 seconds
# Frame number 278 took 1.25962 seconds
# Frame number 279 took 1.28349 seconds
# Frame number 280 took 1.25522 seconds
# Frame number 281 took 1.24767 seconds
# Frame number 282 took 1.25321 seconds
# Frame number 283 took 1.24998 seconds
# Frame number 284 took 1.26691 seconds
# Frame number 285 took 1.24970 seconds
# Frame number 286 took 1.25287 seconds
# Frame number 287 took 1.25051 seconds
# Frame number 288 took 1.25941 seconds
# Frame number 289 took 1.26652 seconds
# Frame number 290 took 1.28175 seconds
# Frame number 291 took 1.26982 seconds
# Frame number 292 took 1.27679 seconds
# Frame number 293 took 1.28703 seconds
# Frame number 294 took 1.26021 seconds
# Frame number 295 took 1.26974 seconds
# Frame number 296 took 1.28991 seconds
# Frame number 297 took 1.25496 seconds
# Frame number 298 took 1.26693 seconds
# Frame number 299 took 1.27346 seconds
# Frame number 300 took 1.26765 seconds
# Frame number 301 took 1.25577 seconds
# Frame number 302 took 1.25884 seconds
# Frame number 303 took 1.27012 seconds
# Frame number 304 took 1.25850 seconds
# Frame number 305 took 1.25411 seconds
# Frame number 306 took 1.28842 seconds
# Frame number 307 took 1.27291 seconds
# Frame number 308 took 1.27125 seconds
# Frame number 309 took 1.29353 seconds
# Frame number 310 took 1.25004 seconds
# Frame number 311 took 1.25918 seconds
# Frame number 312 took 1.25504 seconds
# Frame number 313 took 1.26387 seconds
# Frame number 314 took 1.26432 seconds
# Frame number 315 took 1.26525 seconds
# Frame number 316 took 1.25882 seconds
# Frame number 317 took 1.25515 seconds
# Frame number 318 took 1.25460 seconds
# Frame number 319 took 1.24589 seconds
# Frame number 320 took 1.29370 seconds
# Frame number 321 took 1.24171 seconds
# Frame number 322 took 1.26305 seconds
# Frame number 323 took 1.26854 seconds
# Frame number 324 took 1.25476 seconds
# Frame number 325 took 1.26818 seconds
# Frame number 326 took 1.27009 seconds
# Frame number 327 took 1.25546 seconds
# Frame number 328 took 1.26566 seconds
# Frame number 329 took 1.26127 seconds
# Frame number 330 took 1.26282 seconds
# Frame number 331 took 1.27218 seconds
# Frame number 332 took 1.25558 seconds
# Frame number 333 took 1.26419 seconds
# Frame number 334 took 1.26117 seconds
# Frame number 335 took 1.27094 seconds
# Frame number 336 took 1.30215 seconds
# Frame number 337 took 1.25584 seconds
# Frame number 338 took 1.24452 seconds
# Frame number 339 took 1.27207 seconds
# Frame number 340 took 1.25604 seconds
# Frame number 341 took 1.25408 seconds
# Frame number 342 took 1.28303 seconds
# Frame number 343 took 1.28847 seconds
# Frame number 344 took 1.24781 seconds
# Frame number 345 took 1.25878 seconds
# Frame number 346 took 1.26079 seconds
# Frame number 347 took 1.24886 seconds
# Frame number 348 took 1.26997 seconds
# Frame number 349 took 1.27682 seconds
# Frame number 350 took 1.25590 seconds
# Frame number 351 took 1.26656 seconds
# Frame number 352 took 1.25172 seconds
# Frame number 353 took 1.25038 seconds
# Frame number 354 took 1.25824 seconds
# Frame number 355 took 1.27983 seconds
# Frame number 356 took 1.25087 seconds
# Frame number 357 took 1.27793 seconds
# Frame number 358 took 1.25556 seconds
# Frame number 359 took 1.25727 seconds
# Frame number 360 took 1.25063 seconds
# Frame number 361 took 1.28916 seconds
# Frame number 362 took 1.26950 seconds
# Frame number 363 took 1.27167 seconds
# Frame number 364 took 1.27096 seconds
# Frame number 365 took 1.28316 seconds
# Frame number 366 took 1.27426 seconds
# Frame number 367 took 1.29452 seconds
# Frame number 368 took 1.26018 seconds
# Frame number 369 took 1.25717 seconds
# Frame number 370 took 1.25502 seconds
# Frame number 371 took 1.25689 seconds
# Frame number 372 took 1.25852 seconds
# Frame number 373 took 1.29413 seconds
# Frame number 374 took 1.27485 seconds
# Frame number 375 took 1.26515 seconds
# Frame number 376 took 1.24726 seconds
# Frame number 377 took 1.25684 seconds
# Frame number 378 took 1.26508 seconds
# Frame number 379 took 1.26699 seconds
# Frame number 380 took 1.26003 seconds
# Frame number 381 took 1.24943 seconds
# Frame number 382 took 1.24490 seconds
# Frame number 383 took 1.25309 seconds
# Frame number 384 took 1.27218 seconds
# Frame number 385 took 1.25216 seconds
# Frame number 386 took 1.31175 seconds
# Frame number 387 took 1.41595 seconds
# Frame number 388 took 1.33130 seconds
# Frame number 389 took 1.36398 seconds
# Frame number 390 took 1.48988 seconds
# Frame number 391 took 1.38056 seconds
# Frame number 392 took 1.39378 seconds
# Frame number 393 took 1.54622 seconds
# Frame number 394 took 1.44578 seconds
# Frame number 395 took 1.32178 seconds
# Frame number 396 took 1.33353 seconds
# Frame number 397 took 1.39593 seconds
# Frame number 398 took 1.34656 seconds
# Frame number 399 took 1.33779 seconds
# Frame number 400 took 1.29455 seconds
# Frame number 401 took 1.32962 seconds
# Frame number 402 took 1.31810 seconds
# Frame number 403 took 1.27225 seconds
# Frame number 404 took 1.27467 seconds
# Frame number 405 took 1.24141 seconds
# Frame number 406 took 1.26751 seconds
# Frame number 407 took 1.26159 seconds
# Frame number 408 took 1.24772 seconds
# Frame number 409 took 1.25600 seconds
# Frame number 410 took 1.25870 seconds
# Frame number 411 took 1.27822 seconds
# Frame number 412 took 1.29368 seconds
# Frame number 413 took 1.25850 seconds
# Frame number 414 took 1.25156 seconds
# Frame number 415 took 1.26156 seconds
# Frame number 416 took 1.29928 seconds
# Frame number 417 took 1.25570 seconds
# Frame number 418 took 1.26704 seconds
# Frame number 419 took 1.25148 seconds
# Frame number 420 took 1.25361 seconds
# Frame number 421 took 1.25318 seconds
# Frame number 422 took 1.25130 seconds
# Frame number 423 took 1.28506 seconds
# Frame number 424 took 1.27059 seconds
# Frame number 425 took 1.26223 seconds
# Frame number 426 took 1.25287 seconds
# Frame number 427 took 1.27141 seconds
# Frame number 428 took 1.27370 seconds
# Frame number 429 took 1.26068 seconds
# Frame number 430 took 1.25494 seconds
# Frame number 431 took 1.27990 seconds
# Frame number 432 took 1.24894 seconds
# Frame number 433 took 1.25572 seconds
# Frame number 434 took 1.26848 seconds
# Frame number 435 took 1.24492 seconds
# Frame number 436 took 1.26697 seconds
# Frame number 437 took 1.25250 seconds
# Frame number 438 took 1.29595 seconds
# Frame number 439 took 1.25167 seconds
# Frame number 440 took 1.24979 seconds
# Frame number 441 took 1.26628 seconds
# Frame number 442 took 1.26361 seconds
# Frame number 443 took 1.25836 seconds
# Frame number 444 took 1.27754 seconds
# Frame number 445 took 1.24844 seconds
# Frame number 446 took 1.24481 seconds
# Frame number 447 took 1.25205 seconds
# Frame number 448 took 1.24818 seconds
# Frame number 449 took 1.26792 seconds
# Frame number 450 took 1.27899 seconds
# Frame number 451 took 1.25798 seconds
# Frame number 452 took 1.26073 seconds
# Frame number 453 took 1.27043 seconds
# Frame number 454 took 1.25644 seconds
# Frame number 455 took 1.26722 seconds
# Frame number 456 took 1.25037 seconds
# Frame number 457 took 1.26149 seconds
# Frame number 458 took 1.25511 seconds
# Frame number 459 took 1.27045 seconds
# Frame number 460 took 1.26322 seconds
# Frame number 461 took 1.26995 seconds
# Frame number 462 took 1.27841 seconds
# Frame number 463 took 1.28381 seconds
# Frame number 464 took 1.26186 seconds
# Frame number 465 took 1.27106 seconds
# Frame number 466 took 1.27817 seconds
# Frame number 467 took 1.27027 seconds
# Frame number 468 took 1.28927 seconds
# Frame number 469 took 1.27505 seconds
# Frame number 470 took 1.27114 seconds
# Frame number 471 took 1.26922 seconds
# Frame number 472 took 1.26714 seconds
# Frame number 473 took 1.25956 seconds
# Frame number 474 took 1.26006 seconds
# Frame number 475 took 1.25282 seconds
# Frame number 476 took 1.29389 seconds
# Frame number 477 took 1.27022 seconds
# Frame number 478 took 1.26187 seconds
# Frame number 479 took 1.25768 seconds
# Frame number 480 took 1.25108 seconds
# Frame number 481 took 1.27779 seconds
# Frame number 482 took 1.25352 seconds
# Frame number 483 took 1.29730 seconds
# Frame number 484 took 1.24440 seconds
# Frame number 485 took 1.25840 seconds
# Frame number 486 took 1.25301 seconds
# Frame number 487 took 1.25902 seconds
# Frame number 488 took 1.26816 seconds
# Frame number 489 took 1.25764 seconds
# Frame number 490 took 1.28858 seconds
# Frame number 491 took 1.28861 seconds
# Frame number 492 took 1.28891 seconds
# Frame number 493 took 1.25466 seconds
# Frame number 494 took 1.25503 seconds
# Frame number 495 took 1.27089 seconds
# Frame number 496 took 1.29625 seconds
# Frame number 497 took 1.25620 seconds
# Frame number 498 took 1.26990 seconds
# Frame number 499 took 1.25918 seconds
# Frame number 500 took 1.26898 seconds
# Frame number 501 took 1.27122 seconds
# Frame number 502 took 1.27033 seconds
# Frame number 503 took 1.28185 seconds
# Frame number 504 took 1.25229 seconds
# Frame number 505 took 1.27266 seconds
# Frame number 506 took 1.24709 seconds
# Frame number 507 took 1.27946 seconds
# Frame number 508 took 1.26763 seconds
# Frame number 509 took 1.29954 seconds
# Frame number 510 took 1.28036 seconds
# Frame number 511 took 1.27412 seconds
# Frame number 512 took 1.26216 seconds
# Frame number 513 took 1.25460 seconds
# Frame number 514 took 1.26040 seconds
# Frame number 515 took 1.25553 seconds
# Frame number 516 took 1.29711 seconds
# Frame number 517 took 1.26862 seconds
# Frame number 518 took 1.26489 seconds
# Frame number 519 took 1.26978 seconds
# Frame number 520 took 1.27382 seconds
# Frame number 521 took 1.25930 seconds
# Frame number 522 took 1.26039 seconds
# Frame number 523 took 1.27204 seconds
# Frame number 524 took 1.29081 seconds
# Frame number 525 took 1.25425 seconds
# Frame number 526 took 1.25149 seconds
# Frame number 527 took 1.26664 seconds
# Frame number 528 took 1.26474 seconds
# Frame number 529 took 1.25530 seconds
# Frame number 530 took 1.24336 seconds
# Frame number 531 took 1.31244 seconds
# Frame number 532 took 1.25363 seconds
# Frame number 533 took 1.26266 seconds
# Frame number 534 took 1.26949 seconds
# Frame number 535 took 1.26223 seconds
# Frame number 536 took 1.28910 seconds
# Frame number 537 took 1.25864 seconds
# Frame number 538 took 1.31537 seconds
# Frame number 539 took 1.28733 seconds
# Frame number 540 took 1.26483 seconds
# Frame number 541 took 1.26573 seconds
# Frame number 542 took 1.26874 seconds
# Frame number 543 took 1.27366 seconds
# Frame number 544 took 1.25605 seconds
# Frame number 545 took 1.29239 seconds
# Frame number 546 took 1.26255 seconds
# Frame number 547 took 1.26716 seconds
# Frame number 548 took 1.27720 seconds
# Frame number 549 took 1.26972 seconds
# Frame number 550 took 1.25149 seconds
# Frame number 551 took 1.26834 seconds
# Frame number 552 took 1.28945 seconds
# Frame number 553 took 1.25782 seconds
# Frame number 554 took 1.27755 seconds
# Frame number 555 took 1.25225 seconds
# Frame number 556 took 1.26255 seconds
# Frame number 557 took 1.25347 seconds
# Frame number 558 took 1.29861 seconds
# Frame number 559 took 1.25098 seconds
# Frame number 560 took 1.25648 seconds
# Frame number 561 took 1.26191 seconds
# Frame number 562 took 1.25150 seconds
# Frame number 563 took 1.25448 seconds
# Frame number 564 took 1.28252 seconds
# Frame number 565 took 1.26336 seconds
# Frame number 566 took 1.24782 seconds
# Frame number 567 took 1.26110 seconds
# Frame number 568 took 1.26795 seconds
# Frame number 569 took 1.27476 seconds
# Frame number 570 took 1.26989 seconds
# Frame number 571 took 1.24511 seconds
# Frame number 572 took 1.25742 seconds
# Frame number 573 took 1.25946 seconds
# Frame number 574 took 1.27426 seconds
# Frame number 575 took 1.27580 seconds
# Frame number 576 took 1.25113 seconds
# Frame number 577 took 1.24750 seconds
# Frame number 578 took 1.25502 seconds
# Frame number 579 took 1.27166 seconds
# Frame number 580 took 1.24462 seconds
# Frame number 581 took 1.25620 seconds
# Frame number 582 took 1.24346 seconds
# Frame number 583 took 1.24433 seconds
# Frame number 584 took 1.25796 seconds
# Frame number 585 took 1.26510 seconds
# Frame number 586 took 1.27835 seconds
# Frame number 587 took 1.25249 seconds
# Frame number 588 took 1.24944 seconds
# Frame number 589 took 1.56034 seconds
# Frame number 590 took 1.25496 seconds
# Frame number 591 took 1.28929 seconds
# Frame number 592 took 1.25008 seconds
# Frame number 593 took 1.25168 seconds
# Frame number 594 took 1.25543 seconds
# Frame number 595 took 1.26663 seconds
# Frame number 596 took 1.28663 seconds
# Frame number 597 took 1.24807 seconds
# Frame number 598 took 1.25312 seconds
# Frame number 599 took 1.27540 seconds
# Frame number 600 took 1.28271 seconds
# Frame number 601 took 1.28264 seconds
# Frame number 602 took 1.25100 seconds
# Frame number 603 took 1.25523 seconds
# Frame number 604 took 1.26589 seconds
# Frame number 605 took 1.25791 seconds
# Frame number 606 took 1.28828 seconds
# Frame number 607 took 1.29585 seconds
# Frame number 608 took 1.28255 seconds
# Frame number 609 took 1.29148 seconds
# Frame number 610 took 1.26902 seconds
# Frame number 611 took 1.27205 seconds
# Frame number 612 took 1.27099 seconds
# Frame number 613 took 1.31004 seconds
# Frame number 614 took 1.27688 seconds
# Frame number 615 took 1.26812 seconds
# Frame number 616 took 1.26055 seconds
# Frame number 617 took 1.25398 seconds
# Frame number 618 took 1.25218 seconds
# Frame number 619 took 1.25656 seconds
# Frame number 620 took 1.26127 seconds
# Frame number 621 took 1.25878 seconds
# Frame number 622 took 1.27868 seconds
# Frame number 623 took 1.25641 seconds
# Frame number 624 took 1.26428 seconds
# Frame number 625 took 1.25853 seconds
# Frame number 626 took 1.25711 seconds
# Frame number 627 took 1.27478 seconds
# Frame number 628 took 1.28335 seconds
# Frame number 629 took 1.25414 seconds
# Frame number 630 took 1.26748 seconds
# Frame number 631 took 1.26426 seconds
# Frame number 632 took 1.27179 seconds
# Frame number 633 took 1.26535 seconds
# Frame number 634 took 1.28343 seconds
# Frame number 635 took 1.25527 seconds
# Frame number 636 took 1.25334 seconds
# Frame number 637 took 1.26549 seconds
# Frame number 638 took 1.26076 seconds
# Frame number 639 took 1.25199 seconds
# Frame number 640 took 1.28232 seconds
# Frame number 641 took 1.25975 seconds
# Frame number 642 took 1.25064 seconds
# Frame number 643 took 1.28272 seconds
# Frame number 644 took 1.26940 seconds
# Frame number 645 took 1.27460 seconds
# Frame number 646 took 1.25660 seconds
# Frame number 647 took 1.27839 seconds
# Frame number 648 took 1.27060 seconds
# Frame number 649 took 1.26640 seconds
# Frame number 650 took 1.25721 seconds
# Frame number 651 took 1.26265 seconds
# Frame number 652 took 1.24435 seconds
# Frame number 653 took 1.27467 seconds
# Frame number 654 took 1.26035 seconds
# Frame number 655 took 1.24800 seconds
# Frame number 656 took 1.26377 seconds
# Frame number 657 took 1.24976 seconds
# Frame number 658 took 1.25105 seconds
# Frame number 659 took 1.29773 seconds
# Frame number 660 took 1.25377 seconds
# Frame number 661 took 1.24786 seconds
# Frame number 662 took 1.25510 seconds
# Frame number 663 took 1.25673 seconds
# Frame number 664 took 1.27735 seconds
# Frame number 665 took 1.29190 seconds
# Frame number 666 took 1.25846 seconds
# Frame number 667 took 1.28846 seconds
# Frame number 668 took 1.26807 seconds
# Frame number 669 took 1.26209 seconds
# Frame number 670 took 1.25263 seconds
# Frame number 671 took 1.25328 seconds
# Frame number 672 took 1.25820 seconds
# Frame number 673 took 1.26324 seconds
# Frame number 674 took 1.27646 seconds
# Frame number 675 took 1.27029 seconds
# Frame number 676 took 1.25651 seconds
# Frame number 677 took 1.24818 seconds
# Frame number 678 took 1.25263 seconds
# Frame number 679 took 1.28524 seconds
# Frame number 680 took 1.24773 seconds
# Frame number 681 took 1.27600 seconds
# Frame number 682 took 1.25703 seconds
# Frame number 683 took 1.28499 seconds
# Frame number 684 took 1.25765 seconds
# Frame number 685 took 1.25641 seconds
# Frame number 686 took 1.26971 seconds
# Frame number 687 took 1.26100 seconds
# Frame number 688 took 1.25459 seconds
# Frame number 689 took 1.29830 seconds
# Frame number 690 took 1.25169 seconds
# Frame number 691 took 1.24700 seconds
# Frame number 692 took 1.25969 seconds
# Frame number 693 took 1.27975 seconds
# Frame number 694 took 1.25386 seconds
# Frame number 695 took 1.28881 seconds
# Frame number 696 took 1.26096 seconds
# Frame number 697 took 1.24695 seconds
# Frame number 698 took 1.26901 seconds
# Frame number 699 took 1.25097 seconds
# Frame number 700 took 1.26522 seconds
# Frame number 701 took 1.24941 seconds
# Frame number 702 took 1.28910 seconds
# Frame number 703 took 1.27307 seconds
# Frame number 704 took 1.25124 seconds
# Frame number 705 took 1.25373 seconds
# Frame number 706 took 1.24822 seconds
# Frame number 707 took 1.25654 seconds
# Frame number 708 took 1.28825 seconds
# Frame number 709 took 1.27788 seconds
# Frame number 710 took 1.25601 seconds
# Frame number 711 took 1.25370 seconds
# Frame number 712 took 1.25029 seconds
# Frame number 713 took 1.24998 seconds
# Frame number 714 took 1.27026 seconds
# Frame number 715 took 1.28885 seconds
# Frame number 716 took 1.26669 seconds
# Frame number 717 took 1.26441 seconds
# Frame number 718 took 1.25277 seconds
# Frame number 719 took 1.27904 seconds
# Frame number 720 took 1.25458 seconds
# Frame number 721 took 1.26143 seconds
# Frame number 722 took 1.24894 seconds
# Frame number 723 took 1.26043 seconds
# Frame number 724 took 1.26218 seconds
# Frame number 725 took 1.25139 seconds
# Frame number 726 took 1.25432 seconds
# Frame number 727 took 1.25243 seconds
# Frame number 728 took 1.24075 seconds
# Frame number 729 took 1.24773 seconds
# Frame number 730 took 1.25219 seconds
# Frame number 731 took 1.26008 seconds
# Frame number 732 took 1.28566 seconds
# Frame number 733 took 1.24693 seconds
# Frame number 734 took 1.26608 seconds
# Frame number 735 took 1.24828 seconds
# Frame number 736 took 1.25543 seconds
# Frame number 737 took 1.26356 seconds
# Frame number 738 took 1.25473 seconds
# Frame number 739 took 1.24693 seconds
# Frame number 740 took 1.24795 seconds
# Frame number 741 took 1.24583 seconds
# Frame number 742 took 1.26422 seconds
# Frame number 743 took 1.26886 seconds
# Frame number 744 took 1.24925 seconds
# Frame number 745 took 1.25102 seconds
# Frame number 746 took 1.24691 seconds
# Frame number 747 took 1.25681 seconds
# Frame number 748 took 1.25332 seconds
# Frame number 749 took 1.24738 seconds
# Frame number 750 took 1.25088 seconds
# Frame number 751 took 1.25578 seconds
# Frame number 752 took 1.29410 seconds
# Frame number 753 took 1.24405 seconds
# Frame number 754 took 1.24817 seconds
# Frame number 755 took 1.24842 seconds
# Frame number 756 took 1.26854 seconds
# Frame number 757 took 1.27982 seconds
# Frame number 758 took 1.25225 seconds
# Frame number 759 took 1.25795 seconds
# Frame number 760 took 1.24685 seconds
# Frame number 761 took 1.29777 seconds
# Frame number 762 took 1.26693 seconds
# Frame number 763 took 1.24378 seconds
# Frame number 764 took 1.24824 seconds
# Frame number 765 took 1.25740 seconds
# Frame number 766 took 1.56722 seconds
# Frame number 767 took 2.40748 seconds
# Frame number 768 took 2.39292 seconds
# Frame number 769 took 1.28400 seconds
# Frame number 770 took 1.24270 seconds
# Frame number 771 took 1.25101 seconds
# Frame number 772 took 1.25215 seconds
# Frame number 773 took 1.25082 seconds
# Frame number 774 took 1.26627 seconds
# Frame number 775 took 1.25640 seconds
# Frame number 776 took 1.26992 seconds
# Frame number 777 took 1.26925 seconds
# Frame number 778 took 1.26175 seconds
# Frame number 779 took 1.25888 seconds
# Frame number 780 took 1.26119 seconds
# Frame number 781 took 1.25267 seconds
# Frame number 782 took 1.24539 seconds
# Frame number 783 took 1.26945 seconds
# Frame number 784 took 1.28081 seconds
# Frame number 785 took 1.24447 seconds
# Frame number 786 took 1.26194 seconds
# Frame number 787 took 1.26158 seconds
# Frame number 788 took 1.25613 seconds
# Frame number 789 took 1.25931 seconds
# Frame number 790 took 1.26338 seconds
# Frame number 791 took 1.30286 seconds
# Frame number 792 took 1.24372 seconds
# Frame number 793 took 1.25877 seconds
# Frame number 794 took 1.26416 seconds
# Frame number 795 took 1.27786 seconds
# Frame number 796 took 1.25926 seconds
# Frame number 797 took 1.27840 seconds
# Frame number 798 took 1.28608 seconds
# Frame number 799 took 1.25793 seconds
# Frame number 800 took 1.27512 seconds
# Frame number 801 took 1.25426 seconds
# Frame number 802 took 1.25379 seconds
# Frame number 803 took 1.25559 seconds
# Frame number 804 took 1.27447 seconds
# Frame number 805 took 1.24713 seconds
# Frame number 806 took 1.25446 seconds
# Frame number 807 took 1.27150 seconds
# Frame number 808 took 1.26128 seconds
# Frame number 809 took 1.24783 seconds
# Frame number 810 took 1.24941 seconds
# Frame number 811 took 1.27776 seconds
# Frame number 812 took 1.26680 seconds
# Frame number 813 took 1.27004 seconds
# Frame number 814 took 1.26925 seconds
# Frame number 815 took 1.26544 seconds
# Frame number 816 took 1.25697 seconds
# Frame number 817 took 1.29680 seconds
# Frame number 818 took 1.24969 seconds
# Frame number 819 took 1.25123 seconds
# Frame number 820 took 1.25080 seconds
# Frame number 821 took 1.24943 seconds
# Frame number 822 took 1.26865 seconds
# Frame number 823 took 1.27538 seconds
# Frame number 824 took 1.24236 seconds
# Frame number 825 took 1.25583 seconds
# Frame number 826 took 1.25940 seconds
# Frame number 827 took 1.26143 seconds
# Frame number 828 took 1.25835 seconds
# Frame number 829 took 1.24362 seconds
# Frame number 830 took 1.27239 seconds
# Frame number 831 took 1.25337 seconds
# Frame number 832 took 1.26473 seconds
# Frame number 833 took 1.25835 seconds
# Frame number 834 took 1.25663 seconds
# Frame number 835 took 1.25102 seconds
# Frame number 836 took 1.28510 seconds
# Frame number 837 took 1.26613 seconds
# Frame number 838 took 1.25955 seconds
# Frame number 839 took 1.26693 seconds
# Frame number 840 took 1.25628 seconds
# Frame number 841 took 1.26267 seconds
# Frame number 842 took 1.24889 seconds
# Frame number 843 took 1.29538 seconds
# Frame number 844 took 1.28071 seconds
# Frame number 845 took 1.26147 seconds
# Frame number 846 took 1.29139 seconds
# Frame number 847 took 1.27963 seconds
# Frame number 848 took 1.27504 seconds
# Frame number 849 took 1.26430 seconds
# Frame number 850 took 1.29400 seconds
# Frame number 851 took 1.26378 seconds
# Frame number 852 took 1.28274 seconds
# Frame number 853 took 1.29143 seconds
# Frame number 854 took 1.25349 seconds
# Frame number 855 took 1.27689 seconds
# Frame number 856 took 1.27553 seconds
# Frame number 857 took 1.26464 seconds
# Frame number 858 took 1.29484 seconds
# Frame number 859 took 1.25350 seconds
# Frame number 860 took 1.25012 seconds
# Frame number 861 took 1.26465 seconds
# Frame number 862 took 1.25963 seconds
# Frame number 863 took 1.26241 seconds
# Frame number 864 took 1.27493 seconds
# Frame number 865 took 1.29990 seconds
# Frame number 866 took 1.25529 seconds
# Frame number 867 took 1.26969 seconds
# Frame number 868 took 1.26163 seconds
# Frame number 869 took 1.25667 seconds
# Frame number 870 took 1.27897 seconds
# Frame number 871 took 1.25050 seconds
# Frame number 872 took 1.28117 seconds
# Frame number 873 took 1.28404 seconds
# Frame number 874 took 1.26208 seconds
# Frame number 875 took 1.27663 seconds
# Frame number 876 took 1.26320 seconds
# Frame number 877 took 1.27101 seconds
# Frame number 878 took 1.25308 seconds
# Frame number 879 took 1.25328 seconds
# Frame number 880 took 1.29018 seconds
# Frame number 881 took 1.24880 seconds
# Frame number 882 took 1.25584 seconds
# Frame number 883 took 1.27176 seconds
# Frame number 884 took 1.25943 seconds
# Frame number 885 took 1.26726 seconds
# Frame number 886 took 1.25756 seconds
# Frame number 887 took 1.28445 seconds
# Frame number 888 took 1.25882 seconds
# Frame number 889 took 1.27197 seconds
# Frame number 890 took 1.27074 seconds
# Frame number 891 took 1.26914 seconds
# Frame number 892 took 1.26082 seconds
# Frame number 893 took 1.26116 seconds
# Frame number 894 took 1.28884 seconds
# Frame number 895 took 1.27256 seconds
# Frame number 896 took 1.27456 seconds
# Frame number 897 took 1.25612 seconds
# Frame number 898 took 1.25565 seconds
# Frame number 899 took 1.27564 seconds
# Frame number 900 took 1.25890 seconds
# Frame number 901 took 1.29825 seconds
# Frame number 902 took 1.26567 seconds
# Frame number 903 took 1.26369 seconds
# Frame number 904 took 1.25140 seconds
# Frame number 905 took 1.26086 seconds
# Frame number 906 took 1.25803 seconds
# Frame number 907 took 1.28146 seconds
# Frame number 908 took 1.25449 seconds
# Frame number 909 took 1.26322 seconds
# Frame number 910 took 1.26690 seconds
# Frame number 911 took 1.24478 seconds
# Frame number 912 took 1.25011 seconds
# Frame number 913 took 1.27597 seconds
# Frame number 914 took 1.25528 seconds
# Frame number 915 took 1.26387 seconds
# Frame number 916 took 1.27257 seconds
# Frame number 917 took 1.26599 seconds
# Frame number 918 took 1.25884 seconds
# Frame number 919 took 1.28531 seconds
# Frame number 920 took 1.26578 seconds
# Frame number 921 took 1.27103 seconds
# Frame number 922 took 1.27587 seconds
# Frame number 923 took 1.27591 seconds
# Frame number 924 took 1.26841 seconds
# Frame number 925 took 1.26309 seconds
# Frame number 926 took 1.30217 seconds
# Frame number 927 took 1.25413 seconds
# Frame number 928 took 1.27380 seconds
# Frame number 929 took 1.27321 seconds
# Frame number 930 took 1.27593 seconds
# Frame number 931 took 1.26090 seconds
# Frame number 932 took 1.26468 seconds
# Frame number 933 took 1.30370 seconds
# Frame number 934 took 1.28741 seconds
# Frame number 935 took 1.26803 seconds
# Frame number 936 took 1.27478 seconds
# Frame number 937 took 1.25879 seconds
# Frame number 938 took 1.25268 seconds
# Frame number 939 took 1.27478 seconds
# Frame number 940 took 1.28620 seconds
# Frame number 941 took 1.27435 seconds
# Frame number 942 took 1.33746 seconds
# Frame number 943 took 1.25997 seconds
# Frame number 944 took 1.26616 seconds
# Frame number 945 took 1.25899 seconds
# Frame number 946 took 1.58444 seconds
# Frame number 947 took 1.27785 seconds
# Frame number 948 took 1.26179 seconds
# Frame number 949 took 1.30444 seconds
# Frame number 950 took 1.25541 seconds
# Frame number 951 took 1.27264 seconds
# Frame number 952 took 1.26232 seconds
# Frame number 953 took 1.25749 seconds
# Frame number 954 took 1.26760 seconds
# Frame number 955 took 1.25460 seconds
# Frame number 956 took 1.30016 seconds
# Frame number 957 took 1.26710 seconds
# Frame number 958 took 1.28545 seconds
# Frame number 959 took 1.25525 seconds
# Frame number 960 took 1.25586 seconds
# Frame number 961 took 1.26415 seconds
# Frame number 962 took 1.26365 seconds
# Frame number 963 took 1.27354 seconds
# Frame number 964 took 1.24566 seconds
# Frame number 965 took 1.26133 seconds
# Frame number 966 took 1.26016 seconds
# Frame number 967 took 1.25196 seconds
# Frame number 968 took 1.27702 seconds
# Frame number 969 took 1.26470 seconds
# Frame number 970 took 1.29995 seconds
# Frame number 971 took 1.25921 seconds
# Frame number 972 took 1.26664 seconds
# Frame number 973 took 1.25546 seconds
# Frame number 974 took 1.26566 seconds
# Frame number 975 took 1.27864 seconds
# Frame number 976 took 1.29608 seconds
# Frame number 977 took 1.26068 seconds
# Frame number 978 took 1.27239 seconds
# Frame number 979 took 1.25695 seconds
# Frame number 980 took 1.25631 seconds
# Frame number 981 took 1.25201 seconds
# Frame number 982 took 1.27791 seconds
# Frame number 983 took 1.29053 seconds
# Frame number 984 took 1.26964 seconds
# Frame number 985 took 1.25315 seconds
# Frame number 986 took 1.25911 seconds
# Frame number 987 took 1.26686 seconds
# Frame number 988 took 1.26672 seconds
# Frame number 989 took 1.26828 seconds

# %%
print('Total number of frames', f)
print('Total amount of time {:.5f} seconds'.format(t))
print('FPS:', round((f / t), 1))
# Out:
# Total number of frames 989
# Total amount of time 1256.34071 seconds
# FPS: 0.8

# %%
# Saving locally without committing
from IPython.display import FileLink

FileLink('result.mp4')
# Out:
# /content/result.mp4
